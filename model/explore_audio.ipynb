# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
import sounddevice as sd
import pretty_midi
from new_midi_utils import tensor_to_midi, midi_to_tensor
import seaborn as sns
import torch

# %%
plt.figure(figsize=(25, 10))

prediction = torch.load('prediction.pt', map_location=torch.device("cpu"), weights_only=True)
label = torch.load('label.pt', map_location=torch.device("cpu"), weights_only=True)

plt.subplot(1,2,1)
sns.heatmap(prediction*127)

plt.subplot(1,2,2)
sns.heatmap(label)

plt.show()
